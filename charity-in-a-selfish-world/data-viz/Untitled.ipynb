# %%
import pandas as pd

# %%
import geopandas as gpd

# %%
import matplotlib.pyplot as plt

# %%
dati = pd.read_csv("../data/regioni.csv")
dati.head()
# Out:
#                   data stato  codice_regione denominazione_regione        lat  \
# 0  2020-06-02T17:00:00   ITA              13               Abruzzo  42.351222
# 1  2020-06-02T17:00:00   ITA              17            Basilicata  40.639471
# 2  2020-06-02T17:00:00   ITA              21          P.A. Bolzano  46.499335
# 3  2020-06-02T17:00:00   ITA              18              Calabria  38.905976
# 4  2020-06-02T17:00:00   ITA              15              Campania  40.839566
#
#         long  ricoverati_con_sintomi  terapia_intensiva  totale_ospedalizzati  \
# 0  13.398438                     113                  6                   119
# 1  15.805148                       4                  0                     4
# 2  11.356624                      13                  3                    16
# 3  16.594402                      20                  1                    21
# 4  14.250850                     236                  7                   243
#
# ...

# %%
fp = "../data/dpc-covid-19-ita-aree-comuni.shp"
fp2 = "../data/dpc-covid-19-ita-aree.shp"a

# %%
map_df = gpd.read_file(fp2)

# %%
map_df.head()
# Out:
#   localID  namespace versionID ID_Evento       ID_EventoS nomeLingua  \
# 0       1  IT.PCMDPC         1         1  COVID-19-Italia        ita
# 1       2  IT.PCMDPC         1         1  COVID-19-Italia        ita
# 2       3  IT.PCMDPC         1         1  COVID-19-Italia        ita
# 3       4  IT.PCMDPC         1         1  COVID-19-Italia        ita
# 4       5  IT.PCMDPC         1         1  COVID-19-Italia        ita
#
#        nomeStatus nomeOrigin   nomePronun     nomeFonte  ...     legNumID  \
# 0  standardizzato   endonimo  unpopulated  comISTAT2019  ...  unpopulated
# 1  standardizzato   endonimo  unpopulated  comISTAT2019  ...  unpopulated
# 2  standardizzato   endonimo  unpopulated  comISTAT2019  ...  unpopulated
# 3  standardizzato   endonimo  unpopulated  comISTAT2019  ...  unpopulated
# 4  standardizzato   endonimo  unpopulated  comISTAT2019  ...  unpopulated
#
#      legDocUff  legDataApp   legDataAbr legLivello       legGU_ID  \
# ...

# %%
map_df.plot()
plt.show()

# %%
dati
# Out:
#                    data stato  codice_regione  denominazione_regione  \
# 0   2020-06-02T17:00:00   ITA              13                Abruzzo
# 1   2020-06-02T17:00:00   ITA              17             Basilicata
# 2   2020-06-02T17:00:00   ITA              21           P.A. Bolzano
# 3   2020-06-02T17:00:00   ITA              18               Calabria
# 4   2020-06-02T17:00:00   ITA              15               Campania
# 5   2020-06-02T17:00:00   ITA               8         Emilia-Romagna
# 6   2020-06-02T17:00:00   ITA               6  Friuli Venezia Giulia
# 7   2020-06-02T17:00:00   ITA              12                  Lazio
# 8   2020-06-02T17:00:00   ITA               7                Liguria
# 9   2020-06-02T17:00:00   ITA               3              Lombardia
# 10  2020-06-02T17:00:00   ITA              11                 Marche
# 11  2020-06-02T17:00:00   ITA              14                 Molise
# 12  2020-06-02T17:00:00   ITA               1               Piemonte
# ...

# %%
merge = dati.set_index("codice_regione").join(map_df.set_index('localID'))

# %%
merge.head()
# Out:
#                   data stato  denominazione_regione        lat       long  \
# 1  2020-06-02T17:00:00   ITA               Piemonte  45.073274   7.680687
# 2  2020-06-02T17:00:00   ITA          Valle d'Aosta  45.737503   7.320149
# 3  2020-06-02T17:00:00   ITA              Lombardia  45.466794   9.190347
# 5  2020-06-02T17:00:00   ITA                 Veneto  45.434905  12.338452
# 6  2020-06-02T17:00:00   ITA  Friuli Venezia Giulia  45.649435  13.768136
#
#    ricoverati_con_sintomi  terapia_intensiva  totale_ospedalizzati  \
# 1                     849                 46                   895
# 2                      10                  0                    10
# 3                    3021                166                  3187
# 5                     103                  5                   108
# 6                      40                  2                    42
#
#    isolamento_domiciliare  totale_positivi  ...  legNumID  legDocUff  \
# ...
